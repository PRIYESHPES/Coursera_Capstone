# %% [markdown]
# # Capstone Project

# %% [markdown]
# Welcome, this notebook aims to understand real world data science problems and solve them by working on the Capstone project designed by IBM, herein termed as Capstone Project.

# %%
#import pandas and numpy framework
import pandas as pd
import numpy as np

# %% [markdown]
# Let's print 'Hello Capstone Project Course!' using python's print function

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
